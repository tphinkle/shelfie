# %% [markdown]
# # Analysis
#
# This is a description

# %% [markdown]
# ## Imports

# %%
# Python standard library
import os
import pickle


# Scipy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline






import shelfy
import shelfy.models.similarity
import shelfy.models.utility
from shelfy.models.cosmetics import *
# Out:
# /home/prestonh/anaconda3/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# ## Load data

# %%
books = shelfy.models.utility.unpickle_all_books()

# %% [markdown]
# ## Analysis

# %%
for book in books:
    book.similarity = shelfy.models.similarity.calculate_book_score(book)
# Out:
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none
# title none

# %% [markdown]
# ##### Similarity histogram

# %%
similarities = [book.similarity for book in books if not np.isinf(book.similarity)]

plt.tick_params(labelsize = axistick_size)

n, bins, patches = plt.hist(similarities, fc = histogram_fc, bins = 15, zorder = 10)



plt.title('similarity scores', size = title_size)
plt.xlabel('similarity', size = axislabel_size)
plt.ylabel('count', size = axislabel_size)

plt.grid(zorder = 0)

plt.show()




# Print some values for each bin
for i in range(len(bins) - 1):
    for book in books:
        if book.similarity >= bins[i] and book.similarity < bins[i + 1]:
            print(shelfy.models.similarity.preprocess_book_info(book.book_info))
            print(book.book_info)
            print()
            
            
            #print([word.string for word in book.spine.words])
            #print(book.similarity)
            #print()
# Out:
# ['foundations', 'of', 'statistical', 'natural', 'language', 'processing', 'christopher', 'd', 'manninghinrich', 'schütze', 'mit', 'press']
# {'title': 'Foundations of Statistical Natural Language Processing', 'authors': ['Christopher D. Manning', 'Hinrich Schütze'], 'publisher': 'MIT Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780262133609', 'isbn13': '0262133601'}
#
# ['the', 'innovators', 'dilemma', 'clayton', 'm', 'christensen', 'harperbusiness']
# {'title': "The Innovator's Dilemma", 'authors': ['Clayton M. Christensen'], 'publisher': 'HarperBusiness', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780062060242', 'isbn13': '0062060244'}
#
# ['foundations', 'of', 'statistical', 'natural', 'language', 'processing', 'christopher', 'd', 'manninghinrich', 'schütze', 'mit', 'press']
# {'title': 'Foundations of Statistical Natural Language Processing', 'authors': ['Christopher D. Manning', 'Hinrich Schütze'], 'publisher': 'MIT Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780262133609', 'isbn13': '0262133601'}
#
# ['force', 'of', 'nature', 'jane', 'harper']
# {'title': 'Force of Nature', 'authors': ['Jane Harper'], 'publisher': 'NONE', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1250105633', 'isbn13': '9781250105639'}
#
# ['skinnytaste', 'fast', 'and', 'slow', 'gina', 'homolkaheather', 'k', 'jones', 'clarkson', 'potter']
# {'title': 'Skinnytaste Fast and Slow', 'authors': ['Gina Homolka', 'Heather K. Jones'], 'publisher': 'Clarkson Potter', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0553459600', 'isbn13': '9780553459609'}
#
# ['thinking', 'fast', 'and', 'slow', 'daniel', 'kahneman', 'farrar', 'straus', 'and', 'giroux']
# {'title': 'Thinking, Fast and Slow', 'authors': ['Daniel Kahneman'], 'publisher': 'Farrar, Straus and Giroux', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780374533557', 'isbn13': '0374533555'}
#
# ['thinking', 'fast', 'and', 'slow', 'daniel', 'kahneman', 'farrar', 'straus', 'and', 'giroux']
# {'title': 'Thinking, Fast and Slow', 'authors': ['Daniel Kahneman'], 'publisher': 'Farrar, Straus and Giroux', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780374533557', 'isbn13': '0374533555'}
#
# ['thinking', 'fast', 'and', 'slow', 'daniel', 'kahneman', 'farrar', 'straus', 'and', 'giroux']
# {'title': 'Thinking, Fast and Slow', 'authors': ['Daniel Kahneman'], 'publisher': 'Farrar, Straus and Giroux', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780374533557', 'isbn13': '0374533555'}
#
# ['problem', 'solving', 'with', 'algorithms', 'and', 'data', 'structures', 'using', 'python', 'bradley', 'n', 'millerdavid', 'l', 'ranum', 'franklin', 'beedle', 'assoc']
# {'title': 'Problem Solving with Algorithms and Data Structures Using Python', 'authors': ['Bradley N. Miller', 'David L. Ranum'], 'publisher': 'Franklin Beedle & Assoc', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781590282571', 'isbn13': '1590282574'}
#
# ['python', 'for', 'data', 'analysis', 'wes', 'mckinney', 'oreilly', 'media', 'inc']
# {'title': 'Python for Data Analysis', 'authors': ['Wes McKinney'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449319793', 'isbn13': '9781449319793'}
#
# ['mining', 'engineering', 'analysis', 'christopher', 'j', 'bise', 'sme']
# {'title': 'Mining Engineering Analysis', 'authors': ['Christopher J. Bise'], 'publisher': 'SME', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780873352215', 'isbn13': '0873352211'}
#
# ['data', 'structures', 'and', 'algorithms', 'using', 'python', 'and', 'c', 'david', 'm', 'reedjohn', 'm', 'zelle', 'franklin', 'beedle', 'assoc']
# {'title': 'Data Structures and Algorithms Using Python and C++', 'authors': ['David M. Reed', 'John M. Zelle'], 'publisher': 'Franklin Beedle & Assoc', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781590282335', 'isbn13': '1590282337'}
#
# ['python', 'essential', 'reference', 'david', 'm', 'beazley', 'addisonwesley', 'professional']
# {'title': 'Python Essential Reference', 'authors': ['David M. Beazley'], 'publisher': 'Addison-Wesley Professional', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0672329786', 'isbn13': '9780672329784'}
#
# title none
# []
# {'title': 'NONE', 'authors': 'NONE', 'publisher': 'NONE', 'isbn-10': 'NONE', 'isbn-13': 'NONE'}
#
# ['python', 'for', 'data', 'analysis', 'wes', 'mckinney', 'oreilly', 'media', 'inc']
# {'title': 'Python for Data Analysis', 'authors': ['Wes McKinney'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449319793', 'isbn13': '9781449319793'}
#
# ['natural', 'language', 'processing', 'with', 'python', 'steven', 'birdewan', 'kleinedward', 'loper', 'oreilly', 'media', 'inc']
# {'title': 'Natural Language Processing with Python', 'authors': ['Steven Bird', 'Ewan Klein', 'Edward Loper'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596516495', 'isbn13': '9780596516499'}
#
# ['python', 'for', 'data', 'analysis', 'wes', 'mckinney', 'oreilly', 'media', 'inc']
# {'title': 'Python for Data Analysis', 'authors': ['Wes McKinney'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449319793', 'isbn13': '9781449319793'}
#
# ['python', 'for', 'data', 'analysis', 'wes', 'mckinney', 'oreilly', 'media', 'inc']
# {'title': 'Python for Data Analysis', 'authors': ['Wes McKinney'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449319793', 'isbn13': '9781449319793'}
#
# ['problem', 'solving', 'with', 'algorithms', 'and', 'data', 'structures', 'using', 'python', 'bradley', 'n', 'millerdavid', 'l', 'ranum', 'franklin', 'beedle', 'assoc']
# {'title': 'Problem Solving with Algorithms and Data Structures Using Python', 'authors': ['Bradley N. Miller', 'David L. Ranum'], 'publisher': 'Franklin Beedle & Assoc', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781590282571', 'isbn13': '1590282574'}
#
# ['problem', 'solving', 'with', 'algorithms', 'and', 'data', 'structures', 'using', 'python', 'bradley', 'n', 'millerdavid', 'l', 'ranum', 'franklin', 'beedle', 'assoc']
# {'title': 'Problem Solving with Algorithms and Data Structures Using Python', 'authors': ['Bradley N. Miller', 'David L. Ranum'], 'publisher': 'Franklin Beedle & Assoc', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781590282571', 'isbn13': '1590282574'}
#
# ['natural', 'language', 'processing', 'with', 'python', 'steven', 'birdewan', 'kleinedward', 'loper', 'oreilly', 'media', 'inc']
# {'title': 'Natural Language Processing with Python', 'authors': ['Steven Bird', 'Ewan Klein', 'Edward Loper'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596516495', 'isbn13': '9780596516499'}
#
# ['cartoon', 'guide', 'to', 'statistics', 'larry', 'gonick', 'harper', 'collins']
# {'title': 'Cartoon Guide to Statistics', 'authors': ['Larry Gonick'], 'publisher': 'Harper Collins', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0062731025', 'isbn13': '9780062731029'}
#
# ['revitalize', 'your', 'corporate', 'culture', 'franklin', 'c', 'ashby', 'routledge']
# {'title': 'Revitalize Your Corporate Culture', 'authors': ['Franklin C. Ashby'], 'publisher': 'Routledge', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0884152790', 'isbn13': '9780884152798'}
#
# ['third', 'degree', 'greg', 'iles', 'simon', 'and', 'schuster']
# {'title': 'Third Degree', 'authors': ['Greg Iles'], 'publisher': 'Simon and Schuster', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1416524541', 'isbn13': '9781416524540'}
#
# ['the', 'book', 'of', 'doing', 'and', 'being', 'barnet', 'bain', 'simon', 'and', 'schuster']
# {'title': 'The Book of Doing and Being', 'authors': ['Barnet Bain'], 'publisher': 'Simon and Schuster', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1476785465', 'isbn13': '9781476785462'}
#
# ['doing', 'data', 'science', 'cathy', 'oneilrachel', 'schutt', 'oreilly', 'media']
# {'title': 'Doing Data Science', 'authors': ["Cathy O'Neil", 'Rachel Schutt'], 'publisher': "O'Reilly Media", 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781449358655', 'isbn13': '1449358659'}
#
# ['data', 'structures', 'and', 'algorithms', 'using', 'python', 'and', 'c', 'david', 'm', 'reedjohn', 'm', 'zelle', 'franklin', 'beedle', 'assoc']
# {'title': 'Data Structures and Algorithms Using Python and C++', 'authors': ['David M. Reed', 'John M. Zelle'], 'publisher': 'Franklin Beedle & Assoc', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781590282335', 'isbn13': '1590282337'}
#
# ['pro', 'git', 'scott', 'chacon', 'apress']
# {'title': 'Pro Git', 'authors': ['Scott Chacon'], 'publisher': 'Apress', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781430218333', 'isbn13': '1430218339'}
#
# ['clean', 'code', 'robert', 'c', 'martin', 'pearson', 'education']
# {'title': 'Clean Code', 'authors': ['Robert C. Martin'], 'publisher': 'Pearson Education', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0132350882', 'isbn13': '9780132350884'}
#
# ['a', 'friend', 'of', 'the', 'earth', 'tc', 'boyle']
# {'title': 'A Friend of the Earth', 'authors': ['T.C. Boyle'], 'publisher': 'NONE', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '020161622X'}
#
# ['r', 'cookbook', 'paul', 'teetor', 'oreilly', 'media', 'inc']
# {'title': 'R Cookbook', 'authors': ['Paul Teetor'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596809158', 'isbn13': '9780596809157'}
#
# ['pro', 'git', 'scott', 'chacon', 'apress']
# {'title': 'Pro Git', 'authors': ['Scott Chacon'], 'publisher': 'Apress', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781430218333', 'isbn13': '1430218339'}
#
# ['online', 'andrew', 'harnackgene', 'kleppinger', 'st', 'martins', 'press']
# {'title': 'Online!', 'authors': ['Andrew Harnack', 'Gene Kleppinger'], 'publisher': "St. Martin's Press", 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780312150235', 'isbn13': '0312150237'}
#
# ['introduction', 'to', 'algorithms', 'thomas', 'h', 'cormen', 'mit', 'press']
# {'title': 'Introduction to Algorithms', 'authors': ['Thomas H. Cormen'], 'publisher': 'MIT Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0262033844', 'isbn13': '9780262033848'}
#
# ['mysql', 'paul', 'dubois', 'addisonwesley', 'professional']
# {'title': 'MySQL', 'authors': ['Paul DuBois'], 'publisher': 'Addison-Wesley Professional', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780321833877', 'isbn13': '0321833872'}
#
# ['head', 'first', 'html', 'and', 'css', 'elisabeth', 'robsoneric', 'freeman', 'oreilly', 'media', 'inc']
# {'title': 'Head First HTML and CSS', 'authors': ['Elisabeth Robson', 'Eric Freeman'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596159900', 'isbn13': '9780596159900'}
#
# title none
# []
# {'title': 'NONE', 'authors': 'NONE', 'publisher': 'NONE', 'isbn-10': 'NONE', 'isbn-13': 'NONE'}
#
# ['nosql', 'distilled', 'pramod', 'j', 'sadalagemartin', 'fowler', 'pearson', 'education']
# {'title': 'NoSQL Distilled', 'authors': ['Pramod J. Sadalage', 'Martin Fowler'], 'publisher': 'Pearson Education', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0321826620', 'isbn13': '9780321826626'}
#
# ['mysql', 'crash', 'course', 'ben', 'forta', 'sams', 'publishing']
# {'title': 'MySQL Crash Course', 'authors': ['Ben Forta'], 'publisher': 'Sams Publishing', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0672327120', 'isbn13': '9780672327124'}
#
# ['head', 'first', 'html5', 'programming', 'eric', 'freemanelisabeth', 'robson', 'oreilly', 'media', 'inc']
# {'title': 'Head First HTML5 Programming', 'authors': ['Eric Freeman', 'Elisabeth Robson'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449390544', 'isbn13': '9781449390549'}
#
# ['javascript', 'patterns', 'stoyan', 'stefanov', 'oreilly', 'media', 'inc']
# {'title': 'JavaScript Patterns', 'authors': ['Stoyan Stefanov'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596806752', 'isbn13': '9780596806750'}
#
# ['interactive', 'data', 'visualization', 'for', 'the', 'web', 'scott', 'murray', 'oreilly', 'media', 'inc']
# {'title': 'Interactive Data Visualization for the Web', 'authors': ['Scott Murray'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449339735', 'isbn13': '9781449339739'}
#
# ['statistics', 'done', 'wrong', 'alex', 'reinhart', 'no', 'starch', 'press']
# {'title': 'Statistics Done Wrong', 'authors': ['Alex Reinhart'], 'publisher': 'No Starch Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1593276206', 'isbn13': '9781593276201'}
#
# ['how', 'to', 'measure', 'anything', 'douglas', 'w', 'hubbard', 'john', 'wiley', 'sons']
# {'title': 'How to Measure Anything', 'authors': ['Douglas W. Hubbard'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118539273', 'isbn13': '9781118539279'}
#
# ['hero', 'homecoming', 'r', 'a', 'salvatore', 'wizards', 'of', 'the', 'coast']
# {'title': 'Hero: Homecoming', 'authors': ['R. A. Salvatore'], 'publisher': 'Wizards of the Coast', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780786965960', 'isbn13': '0786965967'}
#
# ['statistics', 'done', 'wrong', 'alex', 'reinhart', 'no', 'starch', 'press']
# {'title': 'Statistics Done Wrong', 'authors': ['Alex Reinhart'], 'publisher': 'No Starch Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1593276206', 'isbn13': '9781593276201'}
#
# ['cracking', 'the', 'coding', 'interview', 'gayle', 'laakmann', 'mcdowell', 'careercup']
# {'title': 'Cracking the Coding Interview', 'authors': ['Gayle Laakmann McDowell'], 'publisher': 'Careercup', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780984782857', 'isbn13': '0984782850'}
#
# ['cracking', 'the', 'coding', 'interview', 'gayle', 'laakmann', 'mcdowell', 'careercup']
# {'title': 'Cracking the Coding Interview', 'authors': ['Gayle Laakmann McDowell'], 'publisher': 'Careercup', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780984782857', 'isbn13': '0984782850'}
#
# ['the', 'book', 'of', 'job', 'stephen', 'mitchell', 'harper', 'perennial']
# {'title': 'The BOOK OF JOB', 'authors': ['Stephen Mitchell'], 'publisher': 'Harper Perennial', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780060969592', 'isbn13': '0060969598'}
#
# ['cracking', 'the', 'coding', 'interview', 'gayle', 'laakmann', 'mcdowell', 'careercup']
# {'title': 'Cracking the Coding Interview', 'authors': ['Gayle Laakmann McDowell'], 'publisher': 'Careercup', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780984782857', 'isbn13': '0984782850'}
#
# ['the', 'secret', 'rhonda', 'byrne', 'simon', 'and', 'schuster']
# {'title': 'The Secret', 'authors': ['Rhonda Byrne'], 'publisher': 'Simon and Schuster', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1582701709', 'isbn13': '9781582701707'}
#
# ['the', 'book', 'of', 'job', 'stephen', 'mitchell', 'harper', 'perennial']
# {'title': 'The BOOK OF JOB', 'authors': ['Stephen Mitchell'], 'publisher': 'Harper Perennial', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780060969592', 'isbn13': '0060969598'}
#
# ['algorithms', 'for', 'interviews', 'adnan', 'azizamit', 'prakash', 'createspace']
# {'title': 'Algorithms for Interviews', 'authors': ['Adnan Aziz', 'Amit Prakash'], 'publisher': 'CreateSpace', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781453792995', 'isbn13': '1453792996'}
#
# ['coming', 'jobs', 'war', 'jim', 'clifton', 'simon', 'and', 'schuster']
# {'title': 'Coming Jobs War', 'authors': ['Jim Clifton'], 'publisher': 'Simon and Schuster', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1595620559', 'isbn13': '9781595620552'}
#
# ['the', 'secret', 'rhonda', 'byrne', 'simon', 'and', 'schuster']
# {'title': 'The Secret', 'authors': ['Rhonda Byrne'], 'publisher': 'Simon and Schuster', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1582701709', 'isbn13': '9781582701707'}
#
# ['cracking', 'the', 'coding', 'interview', 'gayle', 'laakmann', 'mcdowell', 'careercup']
# {'title': 'Cracking the Coding Interview', 'authors': ['Gayle Laakmann McDowell'], 'publisher': 'Careercup', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780984782857', 'isbn13': '0984782850'}
#
# ['elements', 'of', 'programming', 'interviews', 'adnan', 'aziztsunghsien', 'leeamit', 'prakash', 'epi']
# {'title': 'Elements of Programming Interviews', 'authors': ['Adnan Aziz', 'Tsung-Hsien Lee', 'Amit Prakash'], 'publisher': 'EPI', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1479274836', 'isbn13': '9781479274833'}
#
# ['the', 'book', 'of', 'job', 'carol', 'a', 'newsom', 'oxford', 'university', 'press']
# {'title': 'The Book of Job', 'authors': ['Carol A Newsom'], 'publisher': 'Oxford University Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0195396286', 'isbn13': '9780195396287'}
#
# ['quantum', 'theory', 'phillip', 'manning', 'chelsea', 'house', 'pub']
# {'title': 'Quantum Theory', 'authors': ['Phillip Manning'], 'publisher': 'Chelsea House Pub', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781604132953', 'isbn13': '1604132957'}
#
# ['vom', 'zauber', 'der', 'zunge', 'reden', 'gegen', 'das', 'verstummen', 'rafik', 'schami', 'deutscher', 'taschenbuch', 'verlag']
# {'title': 'Vom Zauber der Zunge. Reden gegen das Verstummen.', 'authors': ['Rafik Schami'], 'publisher': 'Deutscher Taschenbuch Verlag', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596529325'}
#
# ['foundation', 'isaac', 'asimov', 'spectra']
# {'title': 'Foundation', 'authors': ['Isaac Asimov'], 'publisher': 'Spectra', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0553293354', 'isbn13': '9780553293357'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['the', 'problem', 'solving', 'memory', 'jogger', 'michael', 'brassardgoalqpc', 'goal', 'q', 'p', 'c', 'incorporated']
# {'title': 'The Problem Solving Memory Jogger', 'authors': ['Michael Brassard', 'GOAL/QPC.'], 'publisher': 'Goal Q P C Incorporated', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781576811351', 'isbn13': '1576811352'}
#
# ['mining', 'the', 'social', 'web', 'matthew', 'a', 'russell', 'oreilly', 'media', 'second', 'edition', 'edition', 'october', '20', '2013']
# {'title': 'Mining the Social Web', 'authors': ['Matthew A. Russell'], 'publisher': "O'Reilly Media; Second Edition edition (October 20, 2013)", 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449367615', 'isbn13': '9781449367619'}
#
# ['cartoon', 'guide', 'to', 'statistics', 'larry', 'gonick', 'harper', 'collins']
# {'title': 'Cartoon Guide to Statistics', 'authors': ['Larry Gonick'], 'publisher': 'Harper Collins', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0062731025', 'isbn13': '9780062731029'}
#
# ['cartoon', 'guide', 'to', 'statistics', 'larry', 'gonick', 'harper', 'collins']
# {'title': 'Cartoon Guide to Statistics', 'authors': ['Larry Gonick'], 'publisher': 'Harper Collins', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0062731025', 'isbn13': '9780062731029'}
#
# ['pro', 'git', 'scott', 'chacon', 'apress']
# {'title': 'Pro Git', 'authors': ['Scott Chacon'], 'publisher': 'Apress', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781430218333', 'isbn13': '1430218339'}
#
# ['html', 'and', 'css', 'jon', 'duckett', 'john', 'wiley', 'sons']
# {'title': 'HTML and CSS', 'authors': ['Jon Duckett'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118008189', 'isbn13': '9781118008188'}
#
# ['mysql', 'paul', 'dubois', 'addisonwesley', 'professional']
# {'title': 'MySQL', 'authors': ['Paul DuBois'], 'publisher': 'Addison-Wesley Professional', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780321833877', 'isbn13': '0321833872'}
#
# ['supercharged', 'javascript', 'graphics', 'raffaele', 'cecco', 'oreilly', 'media', 'inc']
# {'title': 'Supercharged JavaScript Graphics', 'authors': ['Raffaele Cecco'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449393632', 'isbn13': '9781449393632'}
#
# ['javascript', 'patterns', 'stoyan', 'stefanov', 'oreilly', 'media', 'inc']
# {'title': 'JavaScript Patterns', 'authors': ['Stoyan Stefanov'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0596806752', 'isbn13': '9780596806750'}
#
# ['everything', 'you', 'always', 'wanted', 'to', 'know', 'about', 'woody', 'allen', 'the', 'ultimate', 'quiz', 'book', 'frank', 'weimann', 'spi', 'books']
# {'title': 'Everything You Always Wanted to Know About Woody Allen: The Ultimate Quiz Book', 'authors': ['Frank Weimann'], 'publisher': 'S.P.I. Books', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1452654204'}
#
# ['an', 'introduction', 'to', 'statistical', 'learning', 'gareth', 'jamesdaniela', 'wittentrevor', 'hastierobert', 'tibshirani', 'springer']
# {'title': 'An Introduction to Statistical Learning', 'authors': ['Gareth James', 'Daniela Witten', 'Trevor Hastie', 'Robert Tibshirani'], 'publisher': 'Springer', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781461471370', 'isbn13': '1461471370'}
#
# ['how', 'to', 'measure', 'anything', 'douglas', 'w', 'hubbard', 'john', 'wiley', 'sons']
# {'title': 'How to Measure Anything', 'authors': ['Douglas W. Hubbard'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118539273', 'isbn13': '9781118539279'}
#
# ['programming', 'interviews', 'exposed', 'john', 'monganeric', 'giguèrenoah', 'kindler', 'john', 'wiley', 'sons']
# {'title': 'Programming Interviews Exposed', 'authors': ['John Mongan', 'Eric Giguère', 'Noah Kindler'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118261364', 'isbn13': '9781118261361'}
#
# ['leave', 'no', 'child', 'behind', 'preparing', 'todays', 'youth', 'for', 'tomorrows', 'world', 'james', 'p', 'comer', 'yale', 'university', 'press']
# {'title': "Leave No Child Behind: Preparing Today's Youth for Tomorrow's World", 'authors': ['James P. Comer'], 'publisher': 'Yale University Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0071549099'}
#
# ['leave', 'no', 'child', 'behind', 'preparing', 'todays', 'youth', 'for', 'tomorrows', 'world', 'james', 'p', 'comer', 'yale', 'university', 'press']
# {'title': "Leave No Child Behind: Preparing Today's Youth for Tomorrow's World", 'authors': ['James P. Comer'], 'publisher': 'Yale University Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0071549099'}
#
# ['leave', 'no', 'child', 'behind', 'preparing', 'todays', 'youth', 'for', 'tomorrows', 'world', 'james', 'p', 'comer', 'yale', 'university', 'press']
# {'title': "Leave No Child Behind: Preparing Today's Youth for Tomorrow's World", 'authors': ['James P. Comer'], 'publisher': 'Yale University Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0071549099'}
#
# ['leave', 'no', 'child', 'behind', 'preparing', 'todays', 'youth', 'for', 'tomorrows', 'world', 'james', 'p', 'comer', 'yale', 'university', 'press']
# {'title': "Leave No Child Behind: Preparing Today's Youth for Tomorrow's World", 'authors': ['James P. Comer'], 'publisher': 'Yale University Press', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0071549099'}
#
# ['hadoop', 'mapreduce', 'cookbook', 'srinath', 'pererathilina', 'gunarathne', 'packt', 'pub', 'limited']
# {'title': 'Hadoop MapReduce Cookbook', 'authors': ['Srinath Perera', 'Thilina Gunarathne'], 'publisher': 'Packt Pub Limited', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781849517287', 'isbn13': '1849517282'}
#
# ['programming', 'interviews', 'exposed', 'john', 'monganeric', 'giguèrenoah', 'kindler', 'john', 'wiley', 'sons']
# {'title': 'Programming Interviews Exposed', 'authors': ['John Mongan', 'Eric Giguère', 'Noah Kindler'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118261364', 'isbn13': '9781118261361'}
#
# ['manage', 'it', 'johanna', 'rothman']
# {'title': 'Manage It!', 'authors': ['Johanna Rothman'], 'publisher': 'NONE', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780976694021', 'isbn13': '0976694026'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['thinking', 'fast', 'and', 'slow', 'daniel', 'kahneman', 'farrar', 'straus', 'and', 'giroux']
# {'title': 'Thinking, Fast and Slow', 'authors': ['Daniel Kahneman'], 'publisher': 'Farrar, Straus and Giroux', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780374533557', 'isbn13': '0374533555'}
#
# ['the', 'broken', 'cord', 'michael', 'dorrislouise', 'erdrich', 'harper', 'perennial']
# {'title': 'The Broken Cord', 'authors': ['Michael Dorris', 'Louise Erdrich'], 'publisher': 'Harper Perennial', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0387848576'}
#
# ['the', 'broken', 'cord', 'michael', 'dorrislouise', 'erdrich', 'harper', 'perennial']
# {'title': 'The Broken Cord', 'authors': ['Michael Dorris', 'Louise Erdrich'], 'publisher': 'Harper Perennial', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0387848576'}
#
# ['the', 'broken', 'cord', 'michael', 'dorrislouise', 'erdrich', 'harper', 'perennial']
# {'title': 'The Broken Cord', 'authors': ['Michael Dorris', 'Louise Erdrich'], 'publisher': 'Harper Perennial', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '0387848576'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}
#
# ['doing', 'data', 'science', 'cathy', 'oneilrachel', 'schutt', 'oreilly', 'media']
# {'title': 'Doing Data Science', 'authors': ["Cathy O'Neil", 'Rachel Schutt'], 'publisher': "O'Reilly Media", 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9781449358655', 'isbn13': '1449358659'}
#
# ['what', 'is', 'a', 'pvalue', 'anyway', 'andrew', 'vickers', 'addisonwesley', 'longman']
# {'title': 'What is a P-value Anyway?', 'authors': ['Andrew Vickers'], 'publisher': 'Addison-Wesley Longman', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn13': 'UCSD:31822037169695'}
#
# ['programming', 'interviews', 'exposed', 'john', 'monganeric', 'giguèrenoah', 'kindler', 'john', 'wiley', 'sons']
# {'title': 'Programming Interviews Exposed', 'authors': ['John Mongan', 'Eric Giguère', 'Noah Kindler'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118261364', 'isbn13': '9781118261361'}
#
# ['thinking', 'fast', 'and', 'slow', 'daniel', 'kahneman', 'farrar', 'straus', 'and', 'giroux']
# {'title': 'Thinking, Fast and Slow', 'authors': ['Daniel Kahneman'], 'publisher': 'Farrar, Straus and Giroux', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '9780374533557', 'isbn13': '0374533555'}
#
# ['programming', 'interviews', 'exposed', 'john', 'monganeric', 'giguèrenoah', 'kindler', 'john', 'wiley', 'sons']
# {'title': 'Programming Interviews Exposed', 'authors': ['John Mongan', 'Eric Giguère', 'Noah Kindler'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118261364', 'isbn13': '9781118261361'}
#
# ['programming', 'interviews', 'exposed', 'john', 'monganeric', 'giguèrenoah', 'kindler', 'john', 'wiley', 'sons']
# {'title': 'Programming Interviews Exposed', 'authors': ['John Mongan', 'Eric Giguère', 'Noah Kindler'], 'publisher': 'John Wiley & Sons', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1118261364', 'isbn13': '9781118261361'}
#
# ['lean', 'analytics', 'alistair', 'crollbenjamin', 'yoskovitz', 'oreilly', 'media', 'inc']
# {'title': 'Lean Analytics', 'authors': ['Alistair Croll', 'Benjamin Yoskovitz'], 'publisher': '"O\'Reilly Media, Inc."', 'isbn-10': 'NONE', 'isbn-13': 'NONE', 'isbn10': '1449335675', 'isbn13': '9781449335670'}

# %%
for book in books:
    if np.isinf(book.similarity):
        print('unmatched', [word.string for word in book.spine.words])
    else:
        print('matched', [word.string for word in book.spine.words])
        
    print()
# Out:
# unmatched ['and', 'Edition']
#
# matched ['Holmes', 'IC', 'HADOOP', 'IN', 'PRACTICE', '|']
#
# unmatched ['minuty', 'Murray']
#
# unmatched ['Robson']
#
# unmatched ['WILEY']
#
# matched ['ALGORITHMS', 'THIRD', 'EDITION']
#
# unmatched ['INTRODUCTION']
#
# unmatched ['and']
#
# matched ['design', 'and', 'build', 'websites', 'ebsites', 'JON', 'JON', 'DUCKETT', 'DUCKETT']
#
# unmatched ['STEIN', 'of']
#
# unmatched ['TË', 'for', 'Freeman', 'OREILLY']
#
# matched ['DuBois', 'Addison', 'Wesley']
#
# matched ['HTML', 'css', 'Robson']
#
# matched ['.']
#
# matched ['Sad', 'alage', 'Fowler', 'NoSQL', 'Distilled']
#
# matched ['Forta', 'MySQL', '.', 'CRASH', 'COURSE', 'SAMS']
#
# matched ['HTML5', '&']
#
# unmatched ['NUS0322', 'fugare', 'dralysis', 'quam', 'moonium', 'tum', 'wan', 'Igalan']
#
# matched ['JavaScript', 'Patterns']
#
# unmatched ['2nd', 'Updated']
#
# unmatched ['Vue', 'CORMEN', 'LEISERSON', 'RIVEST', 'TO']
#
# unmatched ['FLEREYA', 'Web']
#
# unmatched ['MANNING']
#
# unmatched ['STEIN']
#
# unmatched ['AFFORD', 'O', "'", 'REILLY']
#
# matched ['MySQL', '.', 'Fifth', 'Edition', '14']
#
# matched ['Supercharged', 'JavaScript', 'Graphics', 'Cecco', 'O', "'", 'REILLY']
#
# matched ['Interactive', 'Data', 'Visualization', 'for', 'the']
#
# matched ['Stefanov', 'O', "'", 'REILLY', '"']
#
# unmatched ['IEZS', 'UN', 'N', 'WILEY']

# %% [markdown]
# ##

# %%
print(similarities)

# %%
print(bookss)
