# %% [markdown]
# # Imports

# %%
import json
import numpy
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# %% [markdown]
# # Create SQL DB connection

# %%
# Define a database name (we're using a dataset on births, so we'll call it birth_db)
# Set your postgres username/password, and connection specifics
username = 'postgres'
password = 'password'     # change this
host     = 'localhost'
port     = '5432'            # default port that postgres listens on
db_name  = 'books'




## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine( 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host, port, db_name) )
print(engine.url)






## create a database (if it doesn't exist)
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))




con = psycopg2.connect(database = db_name, user = username, password = password, host = host)
cursor = con.cursor()

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS titles (
                isbn_13 text primary key,
                isbn_10 text,
                title text,
                subtitle text,
                publisher text
               );''')

con.commit()

# %% [markdown]
# # Create titles database

# %%
import random
import string
N = 10
def random_isbn():
    return 'XXX'+''.join(random.choices(string.ascii_uppercase + string.digits, k=N))

# %%
file_name = '../data/jsondump.json'

table_name = 'titles'

batch_size = 10000

with open(file_name, 'r') as file_handle:

    ix = 0
    while True:
        titles = []
        subtitles = [] 
        authors = []
        publishers = []
        isbn10s = []
        isbns13 = []

        print('starting a new block, num_blocks = ', ix)
        ix += 1

        for i in range(batch_size):

            data = next(file_handle)
            json_data = json.loads(data)

            keys = json_data.keys()



            if json_data['type']['key'] == '/type/edition':




                if 'isbn_13' in keys:
                    isbn_13 = json_data['isbn_13'][0]
                else:
                    isbn_13 = random_isbn()


                if 'isbn_10' in keys:
                    isbn_10 = json_data['isbn_10'][0]
                else:
                    isbn_10 = 'NULL'


                if 'title' in keys:
                    title = json_data['title']
                else:
                    title = 'NULL'

                if 'subtitle' in keys:
                    subtitle = json_data['subtitle']
                else:
                    subtitle = 'NULL'

                if 'publishers' in keys:
                    publisher = json_data['publishers'][0]
                else:
                    publisher = []



                command = '''
                INSERT INTO titles (isbn_13, isbn_10, title, subtitle, publisher) VALUES (%s, %s, %s, %s, %s);
                '''

                try:
                    cursor.execute(command, (isbn_13, isbn_10, title, subtitle, publisher))
                except Exception as e:
                    print(str(e))
                    print('error!', ix)
                    con.commit()
                    
                    
                    

        con.commit()
# Out:
# starting a new block, num_blocks =  0
# starting a new block, num_blocks =  1
# starting a new block, num_blocks =  2
# starting a new block, num_blocks =  3
# starting a new block, num_blocks =  4
# starting a new block, num_blocks =  5
# starting a new block, num_blocks =  6
# starting a new block, num_blocks =  7
# starting a new block, num_blocks =  8
# starting a new block, num_blocks =  9
# starting a new block, num_blocks =  10
# starting a new block, num_blocks =  11
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780201712773) already exists.
#
# error! 12
# starting a new block, num_blocks =  12
# starting a new block, num_blocks =  13
# starting a new block, num_blocks =  14
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780738811529) already exists.
#
# error! 15
# starting a new block, num_blocks =  15
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751693) already exists.
#
# error! 16
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751709) already exists.
#
# error! 16
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751655) already exists.
#
# error! 16
# starting a new block, num_blocks =  16
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751662) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751716) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751723) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751679) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751686) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751792) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751778) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751785) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751754) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751761) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751730) already exists.
#
# error! 17
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780373751747) already exists.
#
# error! 17
# starting a new block, num_blocks =  17
# starting a new block, num_blocks =  18
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780393316575) already exists.
#
# error! 19
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780394309910) already exists.
#
# error! 19
# starting a new block, num_blocks =  19
# starting a new block, num_blocks =  20
# starting a new block, num_blocks =  21
# starting a new block, num_blocks =  22
# starting a new block, num_blocks =  23
# starting a new block, num_blocks =  24
# starting a new block, num_blocks =  25
# starting a new block, num_blocks =  26
# starting a new block, num_blocks =  27
# starting a new block, num_blocks =  28
# starting a new block, num_blocks =  29
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780441022557) already exists.
#
# error! 30
# starting a new block, num_blocks =  30
# starting a new block, num_blocks =  31
# starting a new block, num_blocks =  32
# starting a new block, num_blocks =  33
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780595188642) already exists.
#
# error! 34
# starting a new block, num_blocks =  34
# starting a new block, num_blocks =  35
# starting a new block, num_blocks =  36
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780449239742) already exists.
#
# error! 37
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780449235287) already exists.
#
# error! 37
# starting a new block, num_blocks =  37
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780451191144) already exists.
#
# error! 38
# starting a new block, num_blocks =  38
# starting a new block, num_blocks =  39
# starting a new block, num_blocks =  40
# starting a new block, num_blocks =  41
# starting a new block, num_blocks =  42
# starting a new block, num_blocks =  43
# starting a new block, num_blocks =  44
# starting a new block, num_blocks =  45
# starting a new block, num_blocks =  46
# starting a new block, num_blocks =  47
# starting a new block, num_blocks =  48
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(978-0201360615) already exists.
#
# error! 49
# starting a new block, num_blocks =  49
# starting a new block, num_blocks =  50
# starting a new block, num_blocks =  51
# starting a new block, num_blocks =  52
# starting a new block, num_blocks =  53
# starting a new block, num_blocks =  54
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780812096606) already exists.
#
# error! 55
# starting a new block, num_blocks =  55
# starting a new block, num_blocks =  56
# starting a new block, num_blocks =  57
# starting a new block, num_blocks =  58
# starting a new block, num_blocks =  59
# starting a new block, num_blocks =  60
# starting a new block, num_blocks =  61
# starting a new block, num_blocks =  62
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780521336109) already exists.
#
# error! 63
# starting a new block, num_blocks =  63
# starting a new block, num_blocks =  64
# starting a new block, num_blocks =  65
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9781895636178) already exists.
#
# error! 66
# starting a new block, num_blocks =  66
# starting a new block, num_blocks =  67
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780471595205) already exists.
#
# error! 68
# starting a new block, num_blocks =  68
# starting a new block, num_blocks =  69
# starting a new block, num_blocks =  70
# starting a new block, num_blocks =  71
# starting a new block, num_blocks =  72
# starting a new block, num_blocks =  73
# starting a new block, num_blocks =  74
# starting a new block, num_blocks =  75
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780375700309) already exists.
#
# error! 76
# starting a new block, num_blocks =  76
# starting a new block, num_blocks =  77
# starting a new block, num_blocks =  78
# starting a new block, num_blocks =  79
# starting a new block, num_blocks =  80
# starting a new block, num_blocks =  81
# starting a new block, num_blocks =  82
# starting a new block, num_blocks =  83
# starting a new block, num_blocks =  84
# starting a new block, num_blocks =  85
# starting a new block, num_blocks =  86
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(978-0-88011-716-6) already exists.
#
# error! 87
# starting a new block, num_blocks =  87
# starting a new block, num_blocks =  88
# starting a new block, num_blocks =  89
# duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (isbn_13)=(9780375700316) already exists.
#
# error! 90
# starting a new block, num_blocks =  90
# starting a new block, num_blocks =  91
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-3873acdc6787> in <module>()
#      40
#      41                 if 'isbn_10' in keys:
# ---> 42                     isbn_10 = json_data['isbn_10'][0]
#      43                 else:
#      44                     isbn_10 = 'NULL'
#
# IndexError: list index out of range

# %% [markdown]
# # Create authors database

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS authors (
                author_id text primary key,
                author_last_name,
                author_first_name,
               );''')

con.commit()

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS titles_authors (
                isbn_13 text primary key,
                author_id text
               );''')

con.commit()
