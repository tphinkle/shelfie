# %% [markdown]
# # Title matching
#
# Given the actual titles of books on bookshelves (manually entered), queries each of the book information sources for the titles that they return; this is used in order to actually determine whether a true match is made or not when some book information is obtained
#
# Saves the information to the correct place.

# %% [markdown]
# ## Imports

# %%
import csv
import os
import time
import sys


sys.path.append('..')
import main

sys.path.append('../models')
import scraper

# %% [markdown]
# ## Load a bookshelf

# %%
# Set directories
bookshelf_directory = main.SHELFY_BASE_PATH + '/data/shelves/'
bookshelf_name = 'home_6'
bookshelf_path = bookshelf_directory + bookshelf_name + '/titles'


# Output file paths
isbn_output_path = bookshelf_directory + bookshelf_name + '/isbns'
amazon_products_titles_output_path = bookshelf_directory + bookshelf_name + '/titles_amazon_products'



# Read book titles in from plain text file
book_titles = []
with open(bookshelf_path, 'r') as file_handle:
    for book_title in file_handle:
        book_titles.append(book_title.replace('\n', ''))
        
print(book_titles)
# Out:
# ['The Astronomical Almanac 2002', 'The Early Universe Frontiers in Physics', 'Galactic Dynamics', 'The Physics of Stars', 'Galactic Astronomy', 'New Worlds, New Horizons in Astronomy and Astrophysics', 'Modern Cosmology', 'Introduction to Cosmology', 'New Worlds, New Horizons in Astronomy and Astrophysics', 'High Energy Astrophysics', 'Foundations of Astrophysics', '21st Century Astronomy', 'Classical Mechanics', 'Introduction to Quantum Mechanics', 'Introduction to Quantum Mechanics', 'Introduction to Electrodynamics', 'Classical Electrodynamics', 'Modern Quantum Mechanics', 'Modern Quantum Mechanics', 'Statistical Mechanics', 'Classical Dynamics of Particles and Systems', 'Condensed Matter Physics', 'Basic Training in Mathematics', 'Vector Calculus', 'Statistics, Data Mining, and Machine Learning in Astronomy', 'Hands-On Machine Learning with Scikit-Learn and TensorFlow', 'Effective C++ Third Edition', 'Engineering Problem Solving with C++', 'Lectures on Probability Theory and Mathematical Statistics', 'Classical Electrodynamics', 'Introductory combinatorics', 'Basic Training in Mathematics', 'Linear Algebra', 'An Introduction to Error Analysis', 'An Introduction to Quantum Field Theory', 'An Introduction to Thermal Physics', 'Introduction to Electrodynamics', 'Tensor Calculus for Physics', 'Lectures on Quantum Mechanics', 'Statistical Mechanics', 'Statistical Mechanics', 'Methods of Quantum Field Theory', 'Introduction to Solid State Physics', 'Introduction to Classical Mechanics', 'Introduction to Classical Mechanics', 'Classical Mechanics', 'Practical Electronics for Inventors']

# %% [markdown]
# ## Perform the queries

# %%
query_google_urls = [scraper.get_google_search_url_from_query(book_title) for book_title in book_titles]

# %% [markdown]
# ##### Write ISBN's to file

# %%
# Get the info

isbns = []
for i in range(len(query_google_urls)):
    print(i+1, '/', len(query_google_urls))
    
    isbn = None
    while isbn == None:
        isbn = scraper.get_isbn10_from_google_search(query_google_urls[i])
    print(isbn)
    isbns.append(isbn)
# Out:
# 1 / 47
# 0118873156
# 2 / 47
# 0201626748
# 3 / 47
# 0691130272
# 4 / 47
# 0471987980
# 5 / 47
# 0691025657
# 6 / 47
# 0309157994
# 7 / 47
# 0122191412
# 8 / 47
# 0805389121
# 9 / 47
# 0309157994
# 10 / 47
# 0521756189
# 11 / 47
# 0321595580
# 12 / 47
# 0393603326
# 13 / 47
# 189138922X
# 14 / 47
# 1107179866
# 15 / 47
# 1107179866
# 16 / 47
# 1108420419
# 17 / 47
# 0977858278
# 18 / 47
# 0805382917
# 19 / 47
# 0805382917
# 20 / 47
# 0123821886
# 21 / 47
# 0534408966
# 22 / 47
# 0470617985
# 23 / 47
# 0306450364
# 24 / 47
# 1429215089
# 25 / 47
# 0691151687
# 26 / 47
# 1491962291
# 27 / 47
# 0321334876
# 28 / 47
# B009DWN19I
# 29 / 47
# 1480215236
# 30 / 47
# 0977858278
# 31 / 47
# 0136020402
# 32 / 47
# 0306450364
# 33 / 47
# 0030105676
# 34 / 47
# 093570275X
# 35 / 47
# 0813350190
# 36 / 47
# 0201380277
# 37 / 47
# 1108420419
# 38 / 47
# 1421415658
# 39 / 47
# 1107028728
# 40 / 47
# 0123821886
# 41 / 47
# 0123821886
# 42 / 47
# 0486632288
# 43 / 47
# 047141526X
# 44 / 47
# 0521876222
# 45 / 47
# 0521876222
# 46 / 47
# 189138922X
# 47 / 47
# 1259587541

# %%
# Write results to file

with open(isbn_output_path, 'w') as file_handle:
    writer = csv.writer(file_handle, delimiter = ',')
    for isbn in isbns:
        writer.writerow([isbn])

# %% [markdown]
# ##### Load ISBNs

# %%
# Load isbns
isbns = []
with open(isbn_output_path, 'r') as file_handle:
    reader = csv.reader(file_handle, delimiter = ',')
    for isbn in reader:
        isbns.append(isbn[0])
        
print(isbns)
# Out:
# ['0118873156', '0201626748', '0691130272', '0471987980', '0691025657', '0309157994', '0122191412', '0805389121', '0309157994', '0521756189', '0321595580', '0393603326', '189138922X', '1107179866', '1107179866', '1108420419', '0977858278', '0805382917', '0805382917', '0123821886', '0534408966', '0470617985', '0306450364', '1429215089', '0691151687', '1491962291', '0321334876', 'B009DWN19I', '1480215236', '0977858278', '0136020402', '0306450364', '0030105676', '093570275X', '0813350190', '0201380277', '1108420419', '1421415658', '1107028728', '0123821886', '0123821886', '0486632288', '047141526X', '0521876222', '0521876222', '189138922X', '1259587541']

# %% [markdown]
# ##### Amazon Products API

# %%
# Get the info

amazon = scraper.get_amazon_object()
amazon_products_titles = []
for i in range(len(isbns)):
    print(i, '/', len(isbns) - 1)
    
    title = 'NONE'
    
    num_attempts = 0
    while title == 'NONE':
        try:
            num_attempts += 1
            book_info = scraper.query_amazon_products_api(isbns[i], amazon)
            print(book_info)
            title = book_info['title']
            
            
        except:
            print('\tfailed')
            pass
        
        if num_attempts > 10:
            break
        
    print('\t', title, '\t', isbns[i])
    amazon_products_titles.append(title)
# Out:
# 0 / 46
# ({'isbn10': '0118873156', 'title': 'Astronomical Almanac for the Year 2002: Data for Astronomy, Space Sciences, Geodesy, Surveying, Navigation and Other Applications', 'authors': 'U. S. Naval Observatory', 'publisher': 'The Stationery Office/Tso'}, '1500')
# 	failed
# ({'isbn10': '0118873156', 'title': 'Astronomical Almanac for the Year 2002: Data for Astronomy, Space Sciences, Geodesy, Surveying, Navigation and Other Applications', 'authors': 'U. S. Naval Observatory', 'publisher': 'The Stationery Office/Tso'}, '1500')
# 	failed
# ({'isbn10': '0118873156', 'title': 'Astronomical Almanac for the Year 2002: Data for Astronomy, Space Sciences, Geodesy, Surveying, Navigation and Other Applications', 'authors': 'U. S. Naval Observatory', 'publisher': 'The Stationery Office/Tso'}, '1500')
# 	failed
# ({'isbn10': '0118873156', 'title': 'Astronomical Almanac for the Year 2002: Data for Astronomy, Space Sciences, Geodesy, Surveying, Navigation and Other Applications', 'authors': 'U. S. Naval Observatory', 'publisher': 'The Stationery Office/Tso'}, '1500')
# 	failed
# 	 NONE 	 0118873156
# 1 / 46
# ({'isbn10': '0201626748', 'title': 'The Early Universe (Frontiers in Physics)', 'authors': 'Edward Kolb', 'publisher': 'CRC Press'}, '2194')
# 	failed
# ({'isbn10': '0201626748', 'title': 'The Early Universe (Frontiers in Physics)', 'authors': 'Edward Kolb', 'publisher': 'CRC Press'}, '2194')
# 	failed
# ({'isbn10': '0201626748', 'title': 'The Early Universe (Frontiers in Physics)', 'authors': 'Edward Kolb', 'publisher': 'CRC Press'}, '2194')
# 	failed
# ({'isbn10': '0201626748', 'title': 'The Early Universe (Frontiers in Physics)', 'authors': 'Edward Kolb', 'publisher': 'CRC Press'}, '2194')
# 	failed
# 	 NONE 	 0201626748
# 2 / 46
# ({'isbn10': '0691130272', 'title': 'Galactic Dynamics: Second Edition (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '9845')
# 	failed
# ({'isbn10': '0691130272', 'title': 'Galactic Dynamics: Second Edition (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '9845')
# 	failed
# ({'isbn10': '0691130272', 'title': 'Galactic Dynamics: Second Edition (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '9845')
# 	failed
# ({'isbn10': '0691130272', 'title': 'Galactic Dynamics: Second Edition (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '9845')
# 	failed
# 	 NONE 	 0691130272
# 3 / 46
# ({'isbn10': '0471987980', 'title': 'The Physics of Stars', 'authors': 'A. C. Phillips', 'publisher': 'Wiley'}, '5159')
# 	failed
# ({'isbn10': '0471987980', 'title': 'The Physics of Stars', 'authors': 'A. C. Phillips', 'publisher': 'Wiley'}, '5159')
# 	failed
# ({'isbn10': '0471987980', 'title': 'The Physics of Stars', 'authors': 'A. C. Phillips', 'publisher': 'Wiley'}, '5159')
# 	failed
# ({'isbn10': '0471987980', 'title': 'The Physics of Stars', 'authors': 'A. C. Phillips', 'publisher': 'Wiley'}, '5159')
# 	failed
# 	 NONE 	 0471987980
# 4 / 46
# ({'isbn10': '0691025657', 'title': 'Galactic Astronomy (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '4900')
# 	failed
# ({'isbn10': '0691025657', 'title': 'Galactic Astronomy (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '4900')
# 	failed
# 	failed
# ({'isbn10': '0691025657', 'title': 'Galactic Astronomy (Princeton Series in Astrophysics)', 'authors': 'James Binney', 'publisher': 'Princeton University Press'}, '4900')
# 	failed
# 	 NONE 	 0691025657
# 5 / 46
# 	failed
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# 	 NONE 	 0309157994
# 6 / 46
# 	failed
# ({'isbn10': '0122191412', 'title': 'Modern Cosmology', 'authors': 'Scott Dodelson', 'publisher': 'Academic Press'}, '6484')
# 	failed
# ({'isbn10': '0122191412', 'title': 'Modern Cosmology', 'authors': 'Scott Dodelson', 'publisher': 'Academic Press'}, '6484')
# 	failed
# ({'isbn10': '0122191412', 'title': 'Modern Cosmology', 'authors': 'Scott Dodelson', 'publisher': 'Academic Press'}, '6484')
# 	failed
# 	 NONE 	 0122191412
# 7 / 46
# ({'isbn10': '0805389121', 'title': 'Introduction to Cosmology', 'authors': 'Barbara Ryden', 'publisher': 'Addison-Wesley'}, '2308')
# 	failed
# ({'isbn10': '0805389121', 'title': 'Introduction to Cosmology', 'authors': 'Barbara Ryden', 'publisher': 'Addison-Wesley'}, None)
# 	failed
# ({'isbn10': '0805389121', 'title': 'Introduction to Cosmology', 'authors': 'Barbara Ryden', 'publisher': 'Addison-Wesley'}, '2308')
# 	failed
# 	failed
# 	 NONE 	 0805389121
# 8 / 46
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# 	failed
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# ({'isbn10': '0309157994', 'title': 'New Worlds, New Horizons in Astronomy and Astrophysics', 'authors': 'National Research Council', 'publisher': 'National Academies Press'}, '400')
# 	failed
# 	 NONE 	 0309157994
# 9 / 46
# ({'isbn10': '0521756189', 'title': 'High Energy Astrophysics', 'authors': 'Malcolm S. Longair', 'publisher': 'Cambridge University Press'}, '6785')
# 	failed
# 	failed
# ({'isbn10': '0521756189', 'title': 'High Energy Astrophysics', 'authors': 'Malcolm S. Longair', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '0521756189', 'title': 'High Energy Astrophysics', 'authors': 'Malcolm S. Longair', 'publisher': 'Cambridge University Press'}, '6785')
# 	failed
# 	 NONE 	 0521756189
# 10 / 46
# ({'isbn10': '0321595580', 'title': 'Foundations of Astrophysics', 'authors': 'Barbara S. Ryden', 'publisher': 'Addison-Wesley'}, '14073')
# 	failed
# ({'isbn10': '0321595580', 'title': 'Foundations of Astrophysics', 'authors': 'Barbara S. Ryden', 'publisher': 'Addison-Wesley'}, '14073')
# 	failed
# ({'isbn10': '0321595580', 'title': 'Foundations of Astrophysics', 'authors': 'Barbara S. Ryden', 'publisher': 'Addison-Wesley'}, '14073')
# 	failed
# ({'isbn10': '0321595580', 'title': 'Foundations of Astrophysics', 'authors': 'Barbara S. Ryden', 'publisher': 'Addison-Wesley'}, '14073')
# 	failed
# 	 NONE 	 0321595580
# 11 / 46
# ({'isbn10': '0393603326', 'title': '21st Century Astronomy (Fifth Edition)', 'authors': 'Laura Kay', 'publisher': 'W. W. Norton & Company'}, '9995')
# 	failed
# ({'isbn10': '0393603326', 'title': '21st Century Astronomy (Fifth Edition)', 'authors': 'Laura Kay', 'publisher': 'W. W. Norton & Company'}, '9995')
# 	failed
# 	failed
# ({'isbn10': '0393603326', 'title': '21st Century Astronomy (Fifth Edition)', 'authors': 'Laura Kay', 'publisher': 'W. W. Norton & Company'}, '9995')
# 	failed
# 	 NONE 	 0393603326
# 12 / 46
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, '3599')
# 	failed
# 	failed
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, '3599')
# 	failed
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, '3599')
# 	failed
# 	 NONE 	 189138922X
# 13 / 46
# 	failed
# ({'isbn10': '1107179866', 'title': 'Introduction to Quantum Mechanics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, '3295')
# 	failed
# ({'isbn10': '1107179866', 'title': 'Introduction to Quantum Mechanics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# 	failed
# 	 NONE 	 1107179866
# 14 / 46
# ({'isbn10': '1107179866', 'title': 'Introduction to Quantum Mechanics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# 	failed
# 	failed
# ({'isbn10': '1107179866', 'title': 'Introduction to Quantum Mechanics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, '3295')
# 	failed
# 	 NONE 	 1107179866
# 15 / 46
# 	failed
# ({'isbn10': '1108420419', 'title': 'Introduction to Electrodynamics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, '3860')
# 	failed
# 	failed
# 	failed
# 	 NONE 	 1108420419
# 16 / 46
# ({'isbn10': '0977858278', 'title': 'Classical Electrodynamics (Physics)', 'authors': 'Hans Ohanian', 'publisher': 'Jones & Bartlett Learning'}, '2233')
# 	failed
# ({'isbn10': '0977858278', 'title': 'Classical Electrodynamics (Physics)', 'authors': 'Hans Ohanian', 'publisher': 'Jones & Bartlett Learning'}, None)
# 	failed
# ({'isbn10': '0977858278', 'title': 'Classical Electrodynamics (Physics)', 'authors': 'Hans Ohanian', 'publisher': 'Jones & Bartlett Learning'}, '2233')
# 	failed
# 	failed
# 	 NONE 	 0977858278
# 17 / 46
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, '12800')
# 	failed
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, '12800')
# 	failed
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, '12800')
# 	failed
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, '12800')
# 	failed
# 	 NONE 	 0805382917
# 18 / 46
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, '12800')
# 	failed
# 	failed
# 	failed
# ({'isbn10': '0805382917', 'title': 'Modern Quantum Mechanics (2nd Edition)', 'authors': 'J. J. Sakurai', 'publisher': 'Pearson'}, None)
# 	failed
# 	 NONE 	 0805382917
# 19 / 46
# ({'isbn10': '0123821886', 'title': 'Statistical Mechanics, Third Edition', 'authors': 'R K Pathria', 'publisher': 'Academic Press'}, '6644')
# 	failed
# ({'isbn10': '0123821886', 'title': 'Statistical Mechanics, Third Edition', 'authors': 'R K Pathria', 'publisher': 'Academic Press'}, '6644')
# 	failed
# 	failed
# 	failed
# 	 NONE 	 0123821886
# 20 / 46
# 	failed
# ({'isbn10': '0534408966', 'title': 'Classical Dynamics of Particles and Systems', 'authors': 'Stephen T. Thornton', 'publisher': 'Brooks Cole'}, '7800')
# 	failed
# ({'isbn10': '0534408966', 'title': 'Classical Dynamics of Particles and Systems', 'authors': 'Stephen T. Thornton', 'publisher': 'Brooks Cole'}, '7800')
# 	failed
# 	failed
# 	 NONE 	 0534408966
# 21 / 46
# ({'isbn10': '0470617985', 'title': 'Condensed Matter Physics', 'authors': 'Michael P. Marder', 'publisher': 'Wiley'}, '8059')
# 	failed
# ({'isbn10': '0470617985', 'title': 'Condensed Matter Physics', 'authors': 'Michael P. Marder', 'publisher': 'Wiley'}, '8059')
# 	failed
# ({'isbn10': '0470617985', 'title': 'Condensed Matter Physics', 'authors': 'Michael P. Marder', 'publisher': 'Wiley'}, '8059')
# 	failed
# ({'isbn10': '0470617985', 'title': 'Condensed Matter Physics', 'authors': 'Michael P. Marder', 'publisher': 'Wiley'}, None)
# 	failed
# 	 NONE 	 0470617985
# 22 / 46
# ({'isbn10': '0306450364', 'title': 'Basic Training in Mathematics: A Fitness Program for Science Students', 'authors': 'R. Shankar', 'publisher': 'Springer'}, '3500')
# 	failed
# 	failed
# 	failed
# 	failed
# 	 NONE 	 0306450364
# 23 / 46
# 	failed
# ({'isbn10': '1429215089', 'title': 'Vector Calculus', 'authors': 'Jerrold E. Marsden', 'publisher': 'W. H. Freeman'}, '8990')
# 	failed
# 	failed
# 	failed
# 	 NONE 	 1429215089
# 24 / 46
# 	failed
# 	failed
# ({'isbn10': '0691151687', 'title': 'Statistics, Data Mining, and Machine Learning in Astronomy: A Practical Python Guide for the Analysis of Survey Data (Princeton Series in Modern Observational Astronomy)', 'authors': 'Željko Ivezić', 'publisher': 'Princeton University Press'}, '7702')
# 	failed
# ({'isbn10': '0691151687', 'title': 'Statistics, Data Mining, and Machine Learning in Astronomy: A Practical Python Guide for the Analysis of Survey Data (Princeton Series in Modern Observational Astronomy)', 'authors': 'Željko Ivezić', 'publisher': 'Princeton University Press'}, None)
# 	failed
# 	 NONE 	 0691151687
# 25 / 46
# ({'isbn10': '1491962291', 'title': 'Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems', 'authors': 'Aurélien Géron', 'publisher': "O'Reilly Media"}, '1929')
# 	failed
# ({'isbn10': '1491962291', 'title': 'Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems', 'authors': 'Aurélien Géron', 'publisher': "O'Reilly Media"}, None)
# 	failed
# ({'isbn10': '1491962291', 'title': 'Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems', 'authors': 'Aurélien Géron', 'publisher': "O'Reilly Media"}, None)
# 	failed
# ({'isbn10': '1491962291', 'title': 'Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems', 'authors': 'Aurélien Géron', 'publisher': "O'Reilly Media"}, '1929')
# 	failed
# 	 NONE 	 1491962291
# 26 / 46
# 	failed
# ({'isbn10': '0321334876', 'title': 'Effective C++', 'authors': 'Scott (Author) Meyers', 'publisher': 'Addison-Wesley'}, None)
# 	failed
# ({'isbn10': '0321334876', 'title': 'Effective C++', 'authors': 'Scott (Author) Meyers', 'publisher': 'Addison-Wesley'}, '2400')
# 	failed
# 	failed
# 	 NONE 	 0321334876
# 27 / 46
# ({'isbn10': 'B009DWN19I', 'title': 'Engineering Problem Solving with C', 'authors': 'Delores M. Etter', 'publisher': 'Pearson'}, None)
# 	failed
# 	failed
# 	failed
# ({'isbn10': 'B009DWN19I', 'title': 'Engineering Problem Solving with C', 'authors': 'Delores M. Etter', 'publisher': 'Pearson'}, None)
# 	failed
# 	 NONE 	 B009DWN19I
# 28 / 46
# ({'isbn10': '1480215236', 'title': 'Lectures on Probability Theory and Mathematical Statistics - 2nd Edition', 'authors': 'Marco Taboga', 'publisher': 'CreateSpace Independent Publishing Platform'}, None)
# 	failed
# ({'isbn10': '1480215236', 'title': 'Lectures on Probability Theory and Mathematical Statistics - 2nd Edition', 'authors': 'Marco Taboga', 'publisher': 'CreateSpace Independent Publishing Platform'}, None)
# 	failed
# 	failed
# ({'isbn10': '1480215236', 'title': 'Lectures on Probability Theory and Mathematical Statistics - 2nd Edition', 'authors': 'Marco Taboga', 'publisher': 'CreateSpace Independent Publishing Platform'}, '12538')
# 	failed
# 	 NONE 	 1480215236
# 29 / 46
# ({'isbn10': '0977858278', 'title': 'Classical Electrodynamics (Physics)', 'authors': 'Hans Ohanian', 'publisher': 'Jones & Bartlett Learning'}, None)
# 	failed
# 	failed
# 	failed
# 	failed
# 	 NONE 	 0977858278
# 30 / 46
# 	failed
# 	failed
# ({'isbn10': '0136020402', 'title': 'Introductory Combinatorics (5th Edition)', 'authors': 'Richard A. Brualdi', 'publisher': 'Pearson'}, '4995')
# 	failed
# ({'isbn10': '0136020402', 'title': 'Introductory Combinatorics (5th Edition)', 'authors': 'Richard A. Brualdi', 'publisher': 'Pearson'}, '4995')
# 	failed
# 	 NONE 	 0136020402
# 31 / 46
# 	failed
# ({'isbn10': '0306450364', 'title': 'Basic Training in Mathematics: A Fitness Program for Science Students', 'authors': 'R. Shankar', 'publisher': 'Springer'}, None)
# 	failed
# ({'isbn10': '0306450364', 'title': 'Basic Training in Mathematics: A Fitness Program for Science Students', 'authors': 'R. Shankar', 'publisher': 'Springer'}, '3500')
# 	failed
# 	failed
# 	 NONE 	 0306450364
# 32 / 46
# ({'isbn10': '0030105676', 'title': 'Linear Algebra and Its Applications, 4th Edition', 'authors': 'Gilbert Strang', 'publisher': 'Brooks Cole'}, None)
# 	failed
# 	failed
# 	failed
# 	failed
# 	 NONE 	 0030105676
# 33 / 46
# ({'isbn10': '093570275X', 'title': 'Introduction To Error Analysis. Palgrave. 1997.', 'authors': 'John R Taylor', 'publisher': 'University Science Books,U.S.'}, '4450')
# 	failed
# ({'isbn10': '093570275X', 'title': 'Introduction To Error Analysis. Palgrave. 1997.', 'authors': 'John R Taylor', 'publisher': 'University Science Books,U.S.'}, '4450')
# 	failed
# 	failed
# ({'isbn10': '093570275X', 'title': 'Introduction To Error Analysis. Palgrave. 1997.', 'authors': 'John R Taylor', 'publisher': 'University Science Books,U.S.'}, None)
# 	failed
# 	 NONE 	 093570275X
# 34 / 46
# 	failed
# ({'isbn10': '0813350190', 'title': 'An Introduction To Quantum Field Theory, Student Economy Edition (Frontiers in Physics)', 'authors': 'Michael Peskin', 'publisher': 'CRC Press'}, None)
# 	failed
# ({'isbn10': '0813350190', 'title': 'An Introduction To Quantum Field Theory, Student Economy Edition (Frontiers in Physics)', 'authors': 'Michael Peskin', 'publisher': 'CRC Press'}, None)
# 	failed
# ({'isbn10': '0813350190', 'title': 'An Introduction To Quantum Field Theory, Student Economy Edition (Frontiers in Physics)', 'authors': 'Michael Peskin', 'publisher': 'CRC Press'}, None)
# 	failed
# 	 NONE 	 0813350190
# 35 / 46
# 	failed
# ({'isbn10': '0201380277', 'title': 'An Introduction to Thermal Physics', 'authors': 'Daniel V. Schroeder', 'publisher': 'Pearson'}, '4485')
# 	failed
# ({'isbn10': '0201380277', 'title': 'An Introduction to Thermal Physics', 'authors': 'Daniel V. Schroeder', 'publisher': 'Pearson'}, '4485')
# 	failed
# 	failed
# 	 NONE 	 0201380277
# 36 / 46
# 	failed
# 	failed
# ({'isbn10': '1108420419', 'title': 'Introduction to Electrodynamics', 'authors': 'David J. Griffiths', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# 	failed
# 	 NONE 	 1108420419
# 37 / 46
# 	failed
# 	failed
# 	failed
# ({'isbn10': '1421415658', 'title': 'Tensor Calculus for Physics: A Concise Guide', 'authors': 'Dwight E. Neuenschwander', 'publisher': 'Johns Hopkins University Press'}, None)
# 	failed
# 	 NONE 	 1421415658
# 38 / 46
# 	failed
# ({'isbn10': '1107028728', 'title': 'Lectures on Quantum Mechanics', 'authors': 'Steven Weinberg', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '1107028728', 'title': 'Lectures on Quantum Mechanics', 'authors': 'Steven Weinberg', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '1107028728', 'title': 'Lectures on Quantum Mechanics', 'authors': 'Steven Weinberg', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# 	 NONE 	 1107028728
# 39 / 46
# 	failed
# 	failed
# 	failed
# 	failed
# 	 NONE 	 0123821886
# 40 / 46
# ({'isbn10': '0123821886', 'title': 'Statistical Mechanics, Third Edition', 'authors': 'R K Pathria', 'publisher': 'Academic Press'}, '6644')
# 	failed
# 	failed
# ({'isbn10': '0123821886', 'title': 'Statistical Mechanics, Third Edition', 'authors': 'R K Pathria', 'publisher': 'Academic Press'}, '6644')
# 	failed
# 	failed
# 	 NONE 	 0123821886
# 41 / 46
# 	failed
# 	failed
# 	failed
# ({'isbn10': '0486632288', 'title': 'Methods of Quantum Field Theory in Statistical Physics (Dover Books on Physics)', 'authors': 'A. A. Abrikosov', 'publisher': 'Dover Publications'}, None)
# 	failed
# 	 NONE 	 0486632288
# 42 / 46
# 	failed
# 	failed
# 	failed
# ({'isbn10': '047141526X', 'title': 'Introduction to Solid State Physics', 'authors': 'Charles Kittel', 'publisher': 'Wiley'}, '5998')
# 	failed
# 	 NONE 	 047141526X
# 43 / 46
# 	failed
# 	failed
# ({'isbn10': '0521876222', 'title': 'Introduction to Classical Mechanics: With Problems and Solutions', 'authors': 'David Morin', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '0521876222', 'title': 'Introduction to Classical Mechanics: With Problems and Solutions', 'authors': 'David Morin', 'publisher': 'Cambridge University Press'}, '5073')
# 	failed
# 	 NONE 	 0521876222
# 44 / 46
# 	failed
# ({'isbn10': '0521876222', 'title': 'Introduction to Classical Mechanics: With Problems and Solutions', 'authors': 'David Morin', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '0521876222', 'title': 'Introduction to Classical Mechanics: With Problems and Solutions', 'authors': 'David Morin', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# ({'isbn10': '0521876222', 'title': 'Introduction to Classical Mechanics: With Problems and Solutions', 'authors': 'David Morin', 'publisher': 'Cambridge University Press'}, None)
# 	failed
# 	 NONE 	 0521876222
# 45 / 46
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, None)
# 	failed
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, None)
# 	failed
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, '3599')
# 	failed
# ({'isbn10': '189138922X', 'title': 'Classical Mechanics', 'authors': 'John R. Taylor', 'publisher': 'Univ Science Books'}, None)
# 	failed
# 	 NONE 	 189138922X
# 46 / 46
# ({'isbn10': '1259587541', 'title': 'Practical Electronics for Inventors, Fourth Edition', 'authors': 'Paul Scherz', 'publisher': 'McGraw-Hill Education TAB'}, None)
# 	failed
# ({'isbn10': '1259587541', 'title': 'Practical Electronics for Inventors, Fourth Edition', 'authors': 'Paul Scherz', 'publisher': 'McGraw-Hill Education TAB'}, None)
# 	failed
# 	failed
# 	failed
# 	 NONE 	 1259587541

# %%
# Write results to file
with open(amazon_products_titles_output_path, 'w') as file_handle:
    writer = csv.writer(file_handle, delimiter = ',')
    for i in range(len(isbns)):
        writer.writerow([isbns[i], amazon_products_titles[i]])
